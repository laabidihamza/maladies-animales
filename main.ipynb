# %%
import pandas as pd

# %%
print('damn you python3!')
# Out:
# damn you python3!

# %%
df = pd.read_csv('dataset_maladies_animales_selenium_final.csv')
df.head()
# Out:
#        code                                                url  \
# 0  code1050  https://www.elkhabar.com/societe/%D8%A7%D9%84%...
# 1  code1051  https://www.mystateline.com/news/local-news/we...
# 2  code1052  https://www.wattagnet.com/poultry-meat/disease...
# 3  code1053  https://thehorse.com/1128529/2-california-hors...
# 4  code1054                             https://urls.fr/BRHFco
#
#                                                titre  \
# 0                 البليدة: مرض غريب يقضي على الأبقار
# 1                Access to this page has been denied
# 2   More Minnesota turkeys struck by avian influenza
# 3               2 California Horses Positive for EHM
# 4  نفوق الأبقار في عمروسة .. المفتش البيطري بالبل...
#
#                                              contenu   langue  nb_caracteres  \
# 0  الخبر 18/06/2024 - 11:41 البليدة: مرض غريب يقض...    arabe            952
# 1  Your browser appears to have Javascript disabl...  anglais            191
# ...
